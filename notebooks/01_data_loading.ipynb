# %% [markdown]
# # PM Accelerator Weather Forecasting Project
#
# # Notebook 01 — Data Loading
#
# ---
#
# ## Objective
#
# The objective of this notebook is to initialize the project environment,
# load the Global Weather Repository dataset, execute the preprocessing
# pipeline, and verify that the dataset is successfully imported into memory.
#
# This notebook intentionally performs **no exploratory analysis** or
# **data validation**. Those tasks are handled in later notebooks.
#
# ---
#
# ## Inputs
#
# - GlobalWeatherRepository.csv
# - Project configuration
# - Data loading utilities
# - Preprocessing pipeline
#
# ---
#
# ## Outputs
#
# - Loaded pandas DataFrame
# - Preprocessed dataset
# - Verified project environment
#
# ---
#
# ## Expected Deliverables
#
# By the end of this notebook we will have:
#
# - Verified the project environment
# - Successfully loaded the dataset
# - Executed the preprocessing pipeline
# - Produced a DataFrame ready for downstream analysis

# %% [markdown]
# # Workflow
#
# This notebook follows the standardized project workflow.
#
# 1. Configure notebook environment
# 2. Import project modules
# 3. Configure notebook display options
# 4. Load dataset
# 5. Execute preprocessing pipeline
# 6. Verify successful loading
# 7. Save preprocessed DataFrame in memory

# %% [markdown]
# # Imports
#
# Import all required project modules.
#
# Only imports are performed in this section.

# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd().parent

if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

import matplotlib.pyplot as plt
import pandas as pd

from src.data_loader import load_weather_dataset
from src.preprocessing import preprocess_dataset

# %% [markdown]
# # Notebook Configuration
#
# Configure notebook display options.

# %%
pd.set_option("display.max_columns", None)
pd.set_option("display.width", 120)
pd.set_option("display.max_colwidth", None)

plt.rcParams["figure.figsize"] = (12, 6)

# %% [markdown]
# # Load Dataset
#
# Load the raw dataset from disk.

# %%
df = load_weather_dataset()

print(f"Dataset Shape: {df.shape}")
# Out:
# 2026-07-08 13:50:25 | INFO | src.data_loader | Loading weather dataset...
# 2026-07-08 13:50:26 | INFO | src.data_loader | Dataset loaded successfully (151827 rows, 41 columns).
# Dataset Shape: (151827, 41)

# %% [markdown]
# # Preprocessing
#
# Execute the standardized preprocessing pipeline.

# %%
df = preprocess_dataset(df)
# Out:
# 2026-07-08 13:50:26 | INFO | src.preprocessing | ============================================================
# 2026-07-08 13:50:26 | INFO | src.preprocessing | Starting preprocessing pipeline...
# 2026-07-08 13:50:26 | INFO | src.preprocessing | ============================================================
# 2026-07-08 13:50:26 | INFO | src.preprocessing | Converting last_updated to datetime...
# 2026-07-08 13:50:27 | INFO | src.preprocessing | 0 duplicate rows removed.
# 2026-07-08 13:50:27 | INFO | src.preprocessing | Sorting dataset by last_updated...
# 2026-07-08 13:50:27 | INFO | src.preprocessing | Preprocessing complete.

# %% [markdown]
# # Verification
#
# Verify that the dataset has been successfully loaded and preprocessed.

# %%
df.head()
# Out:
#                     country    location_name  latitude  longitude             timezone  last_updated_epoch  \
# 0  United States of America  Washington Park     46.60    -120.49  America/Los_Angeles          1715849100
# 1                Costa Rica         San Juan      9.97     -84.08   America/Costa_Rica          1715849100
# 2                    Mexico      Mexico City     19.43     -99.13  America/Mexico_City          1715849100
# 3               El Salvador     San Salvador     13.71     -89.20  America/El_Salvador          1715849100
# 4                 Guatemala   Guatemala City     14.62     -90.53    America/Guatemala          1715849100
#
#          last_updated  temperature_celsius  temperature_fahrenheit                       condition_text  wind_mph  \
# 0 2024-05-16 01:45:00                 16.1                    61.0                                Clear       4.3
# ...

# %%
df.dtypes.head(10)
# Out:
# country                           object
# location_name                     object
# latitude                         float64
# longitude                        float64
# timezone                          object
# last_updated_epoch                 int64
# last_updated              datetime64[ns]
# temperature_celsius              float64
# temperature_fahrenheit           float64
# condition_text                    object
# dtype: object

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 151827 entries, 0 to 151826
# Data columns (total 41 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   country                       151827 non-null  object
#  1   location_name                 151827 non-null  object
#  2   latitude                      151827 non-null  float64
#  3   longitude                     151827 non-null  float64
#  4   timezone                      151827 non-null  object
#  5   last_updated_epoch            151827 non-null  int64
#  6   last_updated                  151827 non-null  datetime64[ns]
#  7   temperature_celsius           151827 non-null  float64
#  8   temperature_fahrenheit        151827 non-null  float64
#  9   condition_text                151827 non-null  object
#  10  wind_mph                      151827 non-null  float64
#  11  wind_kph                      151827 non-null  float64
# ...

# %% [markdown]
# # Summary
#
# ## Completed
#
# - Project environment configured
# - Dataset successfully loaded
# - Preprocessing pipeline executed
# - Dataset verified
#
# ## Next Notebook
#
# Notebook 02 focuses on validating dataset quality, schema consistency,
# duplicate detection, missing values, and data integrity.
